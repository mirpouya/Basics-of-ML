# %% [markdown]
# <a href="https://colab.research.google.com/github/mirpouya/Basics-of-ML/blob/main/Basics_of_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x)

plt.plot(x,y)

# %%
# scatter plot

# move from the begining, to the end, by step=10
plt.scatter(x[::10], y[::10])

# %%
# two plots in the same figure

plt.plot(x,y,c="b")
plt.plot(x, np.cos(x), c="g")

# %%
# set the style
plt.style.use("classic")

x = np.linspace(0, 100, 1000)
y = np.cumsum(np.random.randn(1000, 5), 0)

plt.plot(x, y)
plt.legend("ABCDE", ncol=2, loc="upper left")

# %%
# working with seaborn

# %%
import seaborn as sns

sns.set()     # sets the style of seaborn

plt.plot(x,y)
plt.legend("ABCDEF", ncol=2, loc="upper left")

# %%
# CREATING A DATASET

X = pd.Series(50*np.random.randn(5000))
Y = pd.Series(200*np.random.randn(5000))
Z = pd.Series(100*np.random.randn(5000)+500)

data = pd.DataFrame({"X":X, "Y":Y, "Z":Z})
data.head()
# Out:
#            X           Y           Z
# 0  13.758967 -268.093547  459.107563
# 1  31.432165 -235.934828  457.850796
# 2  32.590147  229.483734  559.942702
# 3 -15.709117   81.487971  654.143446
# 4 -27.992097   83.228580  575.397049

# %%
# histogram

for col in data.columns:
  plt.hist(data[col], density=True, alpha=0.5)

# %%
plt.hist(data["X"], density=True, alpha=0.5)
# Out:
# (array([6.51155079e-05, 3.84773456e-04, 1.48581750e-03, 4.07859863e-03,
#         7.12126873e-03, 8.01512706e-03, 5.29211492e-03, 2.26128400e-03,
#         7.45868545e-04, 1.47989791e-04]),
#  array([-175.31796925, -141.53185484, -107.74574043,  -73.95962602,
#          -40.17351161,   -6.3873972 ,   27.39871721,   61.18483162,
#           94.97094603,  128.75706044,  162.54317485]),
#  <a list of 10 Patch objects>)
