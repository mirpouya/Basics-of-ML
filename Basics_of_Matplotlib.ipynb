# %% [markdown]
# <a href="https://colab.research.google.com/github/mirpouya/Basics-of-ML/blob/main/Basics_of_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.linspace(0, 10, 1000)
y = np.sin(x)

plt.plot(x,y)

# %%
# scatter plot

# move from the begining, to the end, by step=10
plt.scatter(x[::10], y[::10])

# %%
# two plots in the same figure

plt.plot(x,y,c="b")
plt.plot(x, np.cos(x), c="g")

# %%
# set the style
plt.style.use("classic")

x = np.linspace(0, 100, 1000)
y = np.cumsum(np.random.randn(1000, 5), 0)

plt.plot(x, y)
plt.legend("ABCDE", ncol=2, loc="upper left")

# %%
# working with seaborn

# %%
import seaborn as sns

sns.set()     # sets the style of seaborn

plt.plot(x,y)
plt.legend("ABCDEF", ncol=2, loc="upper left")

# %%
# CREATING A DATASET

X = pd.Series(50*np.random.randn(5000))
Y = pd.Series(200*np.random.randn(5000))
Z = pd.Series(100*np.random.randn(5000)+500)

data = pd.DataFrame({"X":X, "Y":Y, "Z":Z})
data.head()
# Out:
#             X           Y           Z
# 0  -44.768122  102.160828  713.057994
# 1  -19.805233    0.713061  344.071215
# 2 -107.068636   91.667355  548.957954
# 3  -56.523281  170.741473  526.718949
# 4  -34.736002  294.296122  595.875539

# %%
# histogram

for col in data.columns:
  plt.hist(data[col], density=True, alpha=0.5)

# %%
plt.hist(data["X"], density=True, alpha=0.5)
# Out:
# (array([6.35385324e-05, 3.17692662e-04, 1.53647724e-03, 4.34950135e-03,
#         7.20873531e-03, 7.74014849e-03, 5.10041128e-03, 1.94658958e-03,
#         5.37189410e-04, 8.08672231e-05]),
#  array([-177.70578696, -143.08112824, -108.45646952,  -73.8318108 ,
#          -39.20715208,   -4.58249336,   30.04216536,   64.66682408,
#           99.2914828 ,  133.91614152,  168.54080024]),
#  <a list of 10 Patch objects>)

# %%
data.head()
# Out:
#             X           Y           Z
# 0  -44.768122  102.160828  713.057994
# 1  -19.805233    0.713061  344.071215
# 2 -107.068636   91.667355  548.957954
# 3  -56.523281  170.741473  526.718949
# 4  -34.736002  294.296122  595.875539

# %%
# adding surface curvature to the histograms

for col in data.columns:
  plt.hist(data[col], density=True, alpha=0.5)
  sns.kdeplot(data[col], shade=True)   # add surface curve

# %%
# joint plot

# %%
with sns.axes_style("darkgrid"):
  sns.jointplot("X", "Y", data, kind="kde")
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, data. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
"""
pairplot

it alows you to see the distribution of every pair of variables 
visualizing the joint distribution of each two attributes

"""
# Out:
# '\npairplot\n\nit alows you to see the distribution of every pair of variables \nvisualizing the joint distribution of each two attributes\n\n'

# %%
sns.pairplot(data)

# %%
# loading iris dataset

# %%
dataset = np.random.randn(10000)

# %%
plt.hist(dataset)
# Out:
# (array([  10.,   75.,  477., 1540., 2791., 2778., 1665.,  562.,   94.,
#            8.]),
#  array([-3.89371939, -3.12128134, -2.3488433 , -1.57640526, -0.80396721,
#         -0.03152917,  0.74090887,  1.51334691,  2.28578496,  3.058223  ,
#          3.83066104]),
#  <a list of 10 Patch objects>)

# %%
""" 
working with iris data

"""
# Out:
# ' \nworking with iris data\n\n'

# %%
# loading iris

iris_data = sns.load_dataset("iris")
iris_data.head(15)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 3            4.6          3.1           1.5          0.2  setosa
# 4            5.0          3.6           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 11           4.8          3.4           1.6          0.2  setosa
# 12           4.8          3.0           1.4          0.1  setosa
# ...

# %%
# shape

iris_data.shape
# Out:
# (150, 5)

# %%
"""
I want to see the distribution of each class

"""
# Out:
# '\nI want to see the distribution of each class\n\n'

# %%
# pairplots according to "species"

sns.pairplot(iris_data, hue="species")
