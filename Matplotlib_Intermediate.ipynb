# %% [markdown]
# <a href="https://colab.research.google.com/github/mirpouya/Basics-of-ML/blob/main/Matplotlib_Intermediate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("classic")

# %%
# basic plot

fig = plt.figure()
ax = plt.axes()

# %%
# basic plot

plt.style.use("seaborn-darkgrid")
fig = plt.figure()
ax = plt.axes()

# %%
import numpy as np

# %%
# getting started
plt.style.use("classic")
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0,10, 1000)

ax.plot(x, np.sin(x))

# %% [markdown]
# **<h2> Multiple Plots </h2>**

# %%
import math

X = np.arange(0, math.pi*2, 0.05)
  
# Assign variables to the y axis part of the curve
y = np.sin(X)
z = np.cos(X)
  
# Plotting both the curves simultaneously
plt.plot(X, y, color='r', label='sin')
plt.plot(X, z, color='g', label='cos')
  
# Naming the x-axis, y-axis and the whole graph
plt.xlabel("Angle")
plt.ylabel("Magnitude")
plt.title("Sine and Cosine functions")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %%
x = np.linspace(-12, 12, 2400)

y1 = np.cos(x)
y2 = np.tan(x)

plt.plot(x, y1, color="r", label="cos")
plt.plot(x, y2, color="b", label="tan")

# Naming the x-axis, y-axis and the whole graph
plt.xlabel("X")
plt.ylabel("Y")
plt.title("cos and tan functions")

# Adding legend, which helps us recognize the curve according to it's color
plt.legend()

# To load the display window
plt.show()

# %%
# another way of implementing multiple plots in one figure

plt.style.use("seaborn-darkgrid")
fig = plt.figure()
ax = plt.axes()


ax.plot(x, y1*100, color="r", label="y1")
ax.plot(x, y2, color="b", label="y2")
ax.plot(x, x**2 - x**3, color="g", label="y3")

# Naming the x-axis, y-axis and the whole graph
plt.xlabel("Angle")
plt.ylabel("Magnitude")
plt.title("Sine and Cosine functions")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %% [markdown]
# **<h2> Colors and Styles </h2>**

# %%
plt.style.use("seaborn-darkgrid")
fig = plt.figure(figsize=(12,5))   # figure size, first element: width, second element: height
ax = plt.axes()


ax.plot(x, y1*100, color="r", label="y1", linestyle="solid")
ax.plot(x, y2*30, color="b", label="y2", linestyle="dashed")
ax.plot(x, 12*x**2 - x**3, color=(0.1, 0.2, 0.2), label="y3", linestyle="dashdot")   # color in tuple format

# Naming the x-axis, y-axis and the whole graph
plt.xlabel("Angle")
plt.ylabel("Magnitude")
plt.title("Sine and Cosine functions")
  
# Adding legend, which helps us recognize the curve according to it's color
plt.legend()
  
# To load the display window
plt.show()

# %% [markdown]
# **<h2> pyplot vs axes </h2>**

# %% [markdown]
# plt.xlable()   ,   ax.set_xlabel() <br>
# plt.ylabel()   ,   ax.set_ylabel() <br>
# plt.xlim()     ,   ax.set_xlim()   <br>
# plt.ylim()     ,   ax.set_ylim()   <br>
# plt.title()    ,   ax.set_title()  <br>

# %%
# another handy way is to use: as.set(...)

x = np.linspace(-10,10, 3000)
plt.figure(figsize=(10,5))
ax = plt.axes()

ax.plot(x, 4*np.sin(x), label="sin")
ax.plot(x, np.pi*np.cos(x) - 1, label="cos")
ax.plot(x, np.sin(x)**2 + 3*np.cos(x-1), label="function")

ax.set(title="Comparison", xlabel="x", ylabel="function")

plt.axis("equal")
plt.legend(loc="lower right")

# %% [markdown]
# **<h2> Scatter plots </h2>**

# %%
plt.figure(figsize=(10,5))

x = np.random.randn(200)
y = np.random.randn(200)

# color for each point
color = np.random.rand(200)

# size of each point
size = 250*np.random.rand(200)

plt.scatter(x,y, c=color, s=size, alpha=0.5, cmap=plt.cm.viridis)
plt.colorbar()

# %%
# working with iris data

from seaborn import load_dataset

# %%
iris = load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# scatter plot of sepel length vs sepel width

plt.figure(figsize=(10,5))

colors = {'setosa':"red", 'versicolor':"yellow", 'virginica':"blue"}

plt.scatter(iris.sepal_length, iris.sepal_width,c=iris.species.map(colors), cmap=plt.cm.coolwarm) # scatter plot based on species

# %%
iris.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# **<h2> Contour Variables </h2>**

# %%
# working with mesh grids

X, Y = np.meshgrid([-1,1],[5,8])

# %%
# see what happende

print(f"X is :\n {X},\n\n Y is :\n {Y}")
# Out:
# X is :
#  [[-1  1]
#  [-1  1]],
#
#  Y is :
#  [[5 5]
#  [8 8]]

# %% [markdown]
# In fact a joint tuples shapes, -1 with 5, and -1 with 8, 1 with 5, and 1 with 8

# %%
X, Y = np.meshgrid([-1,1,2],[5,8,12])

# %%
print(f"X is :\n {X},\n\n Y is :\n {Y}")
# Out:
# X is :
#  [[-1  1  2]
#  [-1  1  2]
#  [-1  1  2]],
#
#  Y is :
#  [[ 5  5  5]
#  [ 8  8  8]
#  [12 12 12]]

# %%
# generating some data for controur plot

X, Y = np.meshgrid(np.linspace(0,5,50), np.linspace(0,5,40))

# a function of X and Y 
Z = 2*X - 5*np.sin(Y) + 2

# drawing contour plot
plt.figure(figsize=(10,5))
plt.contour(X,Y,Z,30, cmap="RdGy")
plt.colorbar()

# %%
# drawing contour plot
plt.figure(figsize=(10,5))
plt.contourf(X,Y,Z,30, cmap="RdGy")
plt.colorbar()

# %%
# another example

# create data
X, Y = np.meshgrid(np.linspace(5,10,50), np.linspace(5,10,80))

# function of X, Y
F = X+(3*Y)*9*X

# 40 intervals
plt.contourf(X,Y,F,40, cmap=plt.cm.inferno)
plt.colorbar()

# %% [markdown]
# **<h2> Histograms </h2>**

# %%
# data generation

data1 = np.random.normal(0, 0.7, 1000) # normal distribution with mean 0 and std 0.7
data2 = np.random.normal(-5, 2, 1000) # normal distribution with mean -5 and std 2
data3 = np.random.normal(5, 3, 1000) # normal distribution with mean 5 and std 3


# histogram

plt.hist(data1, color="red", label="d1", alpha=0.5)
plt.hist(data2, color="blue", label="d2", alpha=0.5)
plt.hist(data3, color="green", label="d3", alpha=0.5)

plt.legend()

# %%
# using iris dataset

from seaborn import load_dataset
iris = load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.figure(figsize=(10,5))

# defining parameters of histogram
params = dict(histtype="stepfilled", alpha=0.5, bins=30)

plt.hist(iris.sepal_length, **params, color="blue", label="sepal_length")
plt.hist(iris.sepal_width, **params, color="red", label="sepal_width")
plt.hist(iris.petal_length, **params, color="green", label="petal_length")
plt.hist(iris.petal_width, **params, color="yellow", label="petal_width")

# adding legend
plt.legend()

# %% [markdown]
# **<h2> Multiple Plots - Subplots </h2>**

# %%
# starting with defining subplots

fig, ax = plt.subplots(2,3, figsize=(18,6))

# %%
# random plots on each subplot
fig, ax = plt.subplots(2,3, figsize=(18,6))

for i in range(2):
  for j in range(3):
    ax[i,j].plot(np.random.randn(10), np.random.randn(10), "sr")
    #ax[i,j].set(xticks=[], yticks=[])   # disabling text on both axises

# %%
# random images on each subplot
fig, ax = plt.subplots(2,3, figsize=(18,8))

for i in range(2):
  for j in range(3):
    ax[i,j].imshow(np.random.randn(200,200,3))
    #ax[i,j].set(xticks=[], yticks=[])   # disabling text on both axises
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# working with dataset

from sklearn.datasets import fetch_lfw_people

# fetch_lfw_people is a function that returns a dataset

# %%
faces = fetch_lfw_people(min_faces_per_person=70)
faces
# Out:
# {'data': array([[253.66667 , 254.33333 , 253.66667 , ...,  87.      ,  88.      ,
#           86.666664],
#         [ 38.333332,  43.      ,  53.      , ..., 114.666664, 116.666664,
#          143.66667 ],
#         [ 88.      ,  92.666664, 112.666664, ..., 182.66667 , 183.66667 ,
#          182.66667 ],
#         ...,
#         [ 86.333336,  83.333336,  76.333336, ...,  48.      ,  49.      ,
#           40.666668],
#         [ 49.333332,  55.666668,  76.666664, ..., 186.33333 , 176.33333 ,
#          161.      ],
#         [ 31.      ,  26.333334,  28.      , ...,  34.      ,  42.      ,
#           69.666664]], dtype=float32),
#  'images': array([[[253.66667 , 254.33333 , 253.66667 , ...,  56.333332,
#            46.666668,  39.      ],
#          [254.      , 254.      , 253.      , ...,  58.      ,
#            48.333332,  40.666668],
#          [250.      , 247.      , 243.33333 , ...,  56.666668,
#            48.333332,  42.333332],
#          ...,
# ...

# %%
# lets show one of the images
plt.figure(figsize=(8,5))
plt.imshow(faces.images[3], plt.cm.bone)   # face in the index 3

# %%
# visualizing some of the images

fig, ax = plt.subplots(3,7, figsize=(18,8), sharex="col", sharey="row")

k=0
for i in range(3):
  for j in range(7):
    ax[i,j].imshow(faces.images[k], plt.cm.bone)
    k+=1

# %% [markdown]
# **<h2> 3D Plots </h2>**
